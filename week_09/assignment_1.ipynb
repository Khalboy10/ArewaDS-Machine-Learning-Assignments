# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
currency = pd.read_csv('data/currency.csv')
currency.head()
# Out:
#      Time  GEMS_GEMS_SPENT
# 0  5/1/17          1199436
# 1  5/2/17          1045515
# 2  5/3/17           586111
# 3  5/4/17           856601
# 4  5/5/17           793775

# %%
currency.plot(y='GEMS_GEMS_SPENT', figsize=(15, 8))
plt.xlabel('Time')
plt.ylabel('GEMS_GEMS_SPENT')

plt.show()

# %%
ads = pd.read_csv('data/ads_hour.csv')
ads.head()
# Out:
#           Date    ads
# 0  8/3/17 0:00  49136
# 1  8/3/17 1:00  46450
# 2  8/3/17 2:00  46355
# 3  8/3/17 3:00  43748
# 4  8/3/17 4:00  42281

# %%
ads.plot(y='ads', figsize=(15, 8))
plt.xlabel('Date')
plt.ylabel('ads')

plt.show()

# %%
accident = pd.read_csv('data/accidental-deaths-in-usa-monthly.csv')
accident.head()
# Out:
#      Month  Accidental deaths in USA: monthly, 1973 ? 1978
# 0  1973-01                                            9007
# 1  1973-02                                            8106
# 2  1973-03                                            8928
# 3  1973-04                                            9137
# 4  1973-05                                           10017

# %%
accident.plot(y='Accidental deaths in USA: monthly, 1973 ? 1978', figsize=(15, 8))
plt.xlabel('Month')
plt.ylabel('Accident')

plt.show()
